# %% [markdown]
# ---
# title: "My Presentation"
# format: revealjs
# jupyter: python3
# ---

# %% [markdown]
# # Prophet
#
# <img src="media/cover.png" style="width: 40%; display: block; margin: auto;">

# %% [markdown]
# ## Introduction
#
# In this lecture we will learn about [Prophet](https://facebook.github.io/prophet/), a framework for forecasting time series developed by Meta (former Facebook) in 2017.
#
# - Prophet is based on an *additive model* where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects.
# - It works best with time series that have strong seasonal effects and several seasons of historical data.
# - Prophet is robust to missing data, shifts in the trend, and typically handles outliers well.

# %% [markdown]
# In the following, we will cover:
#
# - The main components of the Prophet model: trend, seasonality, and holidays.
# - How to use the prophet library in Python to perform time series forecasting.
# - Try more advanced options and configurations available within the Python library.

# %%
# Imports
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %% [markdown]
# ---

# %% [markdown]
# ## Model components

# %% [markdown]
# - Prophet models a time series $y(t)$ as a combination of three components:
#
#   1. trend $g(t)$,
#   2. seasonality $s(t)$,
#   3. holidays $h(t)$.

# %% [markdown]
# - The model equation is:
#
# $$y(t) = g(t) + s(t) + h(t) + \epsilon_t$$
#
# - where $\epsilon_t$ is the error term assumed to be normally distributed.

# %% [markdown]
# ### Trend component $g(t)$
#
# - The trend component models non-periodic changes in the value of the time series.
# - Prophet provides two options for modeling the trend:
#   - Piece-wise linear growth model.
#   - Logistic growth model.

# %% [markdown]
# #### Piece-wise linear growth model
#
# - A piece-wise linear function can accommodate changes in the trend's direction over time.
# - This is particularly useful for time series data exhibiting shifts in growth rates due to external factors or internal changes.
# - This allows to capture and forecast time series trends that do not follow a specific form (linear or logistic).

# %% [markdown]
# - In a piece-wise linear trend model, the time series is divided into *segments*.
# - In each segment, the trend is modeled as a linear function.
# - The points where the trend changes direction are called *change points*.

# %% [markdown]
# - Prophet allows users to specify the *maximum number* of potential change points or to let the algorithm automatically estimate it based on the data.
# - Prophet automatically detects the change points, allowing the trend to adjust its slope at these points, hence capturing shifts in the trend's direction.

# %% [markdown]
# - Users can adjust the flexibility of the model in capturing trend changes by tuning the change point *prior scale* parameter.
#     - A higher prior scale makes the model more sensitive to changes (allowing more flexibility).
#     - A lower prior scale makes the model less sensitive to fluctuations (resulting in a smoother trend).

# %% [markdown]
# The piece-wise linear trend model in Prophet is defined as:
#
# $$g(t) = (k + a(t)^\top \delta) \cdot t + (g_0 + a(t)^\top \gamma)$$
#
# where:
# - $g(t)$ is the trend component at time $t$,
# - $k$ is the initial growth rate,
# - $a(t)$ is time since the corresponding change point if $t$ is after a change point, or 0 otherwise,
# - $\delta$ represents adjustments to the growth rate at each change point,
# - $g_0$ is the offset (intercept), i.e., the value at $t=0$,
# - $\gamma$ smooths the trend at each change point.

# %%
def compute_a(t, change_points):
    #return np.array([max(0, t - cp) for cp in change_points])
    return np.array([np.heaviside(t - cp, 1) for cp in change_points])

def compute_g(t, k, delta, g0, gamma, change_points):
    a_t = compute_a(t, change_points)
    trend = (k + np.dot(a_t, delta)) * t + (g0 + np.dot(a_t, gamma))
    return trend

# %%
change_points = [3, 7, 11, 16]             # Times at which changes occur
k = 0.3                                # Initial growth rate
delta = np.array([0.1, -0.2, -0.1, 0.3])    # Adjustments to growth rate
g0 = 2.0                               # Initial offset
gamma = -delta*np.array(change_points) # Compensations for discontinuities

time_points = np.linspace(0, 20, 200) 
g_values = [compute_g(t, k, delta, g0, gamma, change_points) for t in time_points]

# %%
plt.figure(figsize=(7, 3))
plt.plot(time_points, g_values, label="Piecewise Linear Trend")
plt.scatter(change_points, [compute_g(cp, k, delta, g0, gamma, change_points) for cp in change_points], color='tab:red', label="Change Points")
plt.xlabel("Time")
plt.ylabel("g(t)")
plt.legend()
plt.grid(True)
plt.tight_layout();

# %% [markdown]
# > **🛠️ Try it yourself**
# >
# > Try modifying the parameters `change_points`, `k`,  `delta`, `g0`, and `gamma` to see how piece-wise linear trend above change.

# %% [markdown]
# #### Logistic growth model
#
# The Logistic growth model is used to describe a population that:
# - Grows rapidly when it's small.
# - Grows slowlier as it approaches a maximum limit (*carrying capacity*) that it cannot exceed.
# - Eventually levels off when the carrying capacity is reached (*saturating growth*).

# %% [markdown]
# *Carrying capacity*
#
# - Is a concept borrowed from population biology.
# - It refers to the maximum population size that an environment can sustain without being degraded.
# - For business metrics, this could represent a market saturation point, such as the maximum number of users a platform can support due to limitations in infrastructure or market size.

# %% [markdown]
# *Saturating growth*
#
# - It refers to a growth pattern where increments become progressively smaller as the value approaches the carrying capacity.
# - When the values are far below the carrying capacity, growth can be rapid (there is a lot of "room" to grow).
# - As the values approach the carrying capacity, the growth rate decreases, and the time series levels off, reflecting a saturation point where further growth becomes increasingly difficult.

# %% [markdown]
# The formula describing the Logistic trend is:
#
# $$g(t) = \frac{C}{1 + e^{-k(t - m)}}$$
#
# where:
# - $k$ is the growth rate,
# - $C$ is the carrying capacity (the maximum achievable value),
# - $t$ is time,
# - $m$ is the point in time where growth is halfway to the carrying capacity.

# %%
def logistic_growth(t, C, k, m):
    return C / (1 + np.exp(-k * (t - m)))

# Parameters
C = 800   # carrying capacity
k = 0.6  # growth rate
m = 20    # offset parameter, indicating the inflection point

t = np.linspace(0, 120, 200)
y = logistic_growth(t, C, k, m)

# %%
plt.figure(figsize=(7, 3))
plt.plot(t, y, label='Logistic growth')
plt.xlabel('Time')
plt.ylabel('Value')
plt.axhline(C, color='tab:red', linestyle='--', label='Carrying capacity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > 🛠️ Try it yourself**
# >
# > - Try setting `m=20` to see how the curve changes.
# > - Try also modifying the values of `k` and `C`.

# %% [markdown]
# ### Seasonality component $s(t)$
#
# The seasonality component $s(t)$ models periodic changes, which can be yearly, weekly, or daily.
#
# Prophet uses Fourier series to model these periodic changes, allowing for flexibility in capturing seasonality.

# %% [markdown]
# Seasonality $s(t)$ is defined as:
#
# $$s(t) = \sum_{n=1}^{N} \left(a_n \cos\left(\frac{2\pi n t}{P}\right) + b_n \sin\left(\frac{2\pi n t}{P}\right)\right)$$
#
# where:
# - $N$ is the number of Fourier terms (higher $N$ captures more detailed seasonal patterns),
# - $P$ is the period (e.g., 365.25 for yearly seasonality),
# - $a_n$ and $b_n$ are the Fourier series coefficients that are fitted to the data.

# %% [markdown]
# ### Holidays and events $h(t)$
#
# - The holiday component $h(t)$ models irregular - but predictable - events.
# - This component is represented as a series of indicator functions that equal 1 if the time $t$ corresponds to a holiday and 0 otherwise.
# - Coefficients associated with these indicators are fitted to measure the impact of holidays on the forecast.

# %% [markdown]
# The holiday component $h(t)$ is defined as
#
# $$h(t) = \sum_{i} I(t \in D_i) \cdot \delta_i$$
#
# where:
# - $D_i$ represents the set of times corresponding to holiday $i$,
# - $I$ is an indicator function,
# - $\delta_i$ is the effect of holiday $i$ on the time series, which can be tuned.

# %% [markdown]
# #### Seasonal and holiday effects adjustment
#
# - Like for piece-wise linear trend, Prophet can adjust for overfitting or underfitting of seasonal and holiday effects by changing a *prior scale* parameter.
# - A *larger* prior scale allows the model to fit larger seasonal fluctuations.
# - A *smaller* scale regularizes the model, preventing it from overfitting seasonal and holiday effects.
#
# ---

# %% [markdown]
# ## Fitting the Model

# %% [markdown]
# - The components described above are combined into the overall model.
# - To fit the Prophet model to historical data the model's parameters are estimated using maximum likelihood estimation or Bayesian sampling.
# - This involves optimizing the parameters to minimize the difference between the observed and predicted values of the time series.

# %% [markdown]
# - The optimization is usually done through gradient descent methods.
# - To perform the optimization Prophet relies on [Stan](https://mc-stan.org/), a C++ library for statistical modeling and high-performance statistical computation that makes model fitting very fast.
#
# ---

# %% [markdown]
# ## Prophet in Python

# %% [markdown]
# - The input to Prophet is always a dataframe with two columns: `ds` and `y`.
# - Be sure to rename your dataframe with these column names.
# - The `ds` (datestamp) column should be of a format expected by Pandas, ideally YYYY-MM-DD for a date or YYYY-MM-DD HH:MM:SS for a timestamp.
# - The `y` column must be numeric, and represents the measurement we wish to forecast.

# %% [markdown]
# - As an example, we'll look at a time series of daily page views for the Wikipedia page of [Peyton Manning](https://en.wikipedia.org/wiki/Peyton_Manning), a former football player.
# - This is a nice example because it illustrates some of Prophet’s features, like multiple seasonality, changing growth rates, and the ability to model special days (such as Manning’s playoff and superbowl appearances).

# %%
data_path = 'https://raw.githubusercontent.com/PinkWink/DataScience/master/data/07.%20example_wp_peyton_manning.csv'
peyton = pd.read_csv(data_path)
peyton.head()
# Out:
#            ds      y
# 0  2007-12-10  14629
# 1  2007-12-11   5012
# 2  2007-12-12   3582
# 3  2007-12-13   3205
# 4  2007-12-14   2680

# %%
peyton.plot(figsize=(14, 4), grid=True);

# %% [markdown]
# - Since there are big spikes in the data, we will apply a logarithm transformation to obtain a more even range of variation in the data.

# %%
peyton['y'] = np.log(peyton['y'])
peyton.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %% [markdown]
# - The log transformation clearly stabilized the variance in the data, as we can see from the plot.

# %%
peyton.plot(figsize=(14, 4), grid=True);

# %% [markdown]
# - Next, we instantiate a new Prophet object.
# - We can specify several parameters such as:
#   - `growth='linear'`, meaning that we use a piece-wise linear function to model the trend. Other options are `'logistic'` or `'flat'` to specify a logistic or flat trend, respectively.
#   - `seasonality_mode='additive'`. The other option is `'multiplicative'`.
#   - `interval_width=0.90` specifies the width of the prediction intervals for the forecast.

# %%
model = Prophet(growth='linear', seasonality_mode='additive', interval_width=0.90)

# %% [markdown]
# - Once the model is instantiated, we call its fit method and pass to it the historical dataframe.
# - Fitting should take 1-2 seconds.

# %%
model.fit(peyton);
# Out:
# 15:13:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:13:48 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# - Predictions are then made on a dataframe with a column `ds` containing the dates for which a prediction is to be made.
# - You can get a suitable dataframe that extends into the future a specified number of days using the helper method `Prophet.make_future_dataframe`.
# - `periods=365` specifies the length of our forecast.
# - `freq='D'` specifies that the units (`365` in this case) represent days.
# - By setting `include_history=True` it will also include the dates used for training, so we can also see the model.

# %%
future = model.make_future_dataframe(periods=365, freq='D', include_history=True)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %% [markdown]
# - The `predict` method will assign each row in `future` a predicted value `yhat`.
# - By giving also historical dates (`include_history=True`), it will provide an in-sample fit.
# - The `forecast` object here is a new dataframe that includes a column `yhat` with the forecast and many other columns, including those with uncertainty intervals.

# %%
forecast = model.predict(future)
forecast.tail()
# Out:
#              ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 3265 2017-01-15  7.185052    7.251478    9.129018     6.706926     7.677907
# 3266 2017-01-16  7.184020    7.613682    9.483139     6.702393     7.678231
# 3267 2017-01-17  7.182988    7.348932    9.281152     6.697860     7.679410
# 3268 2017-01-18  7.181957    7.187075    9.090478     6.693326     7.680589
# 3269 2017-01-19  7.180925    7.207329    9.058918     6.688811     7.681768
#
#       additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 3265        1.018148              1.018148              1.018148  0.048256
# 3266        1.344221              1.344221              1.344221  0.352303
# 3267        1.132648              1.132648              1.132648  0.119651
# 3268        0.966266              0.966266              0.966266 -0.066662
# 3269        0.979215              0.979215              0.979215 -0.072249
#
#       weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 3265      0.048256      0.048256  0.969892      0.969892      0.969892
# 3266      0.352303      0.352303  0.991918      0.991918      0.991918
# 3267      0.119651      0.119651  1.012997      1.012997      1.012997
# 3268     -0.066662     -0.066662  1.032928      1.032928      1.032928
# 3269     -0.072249     -0.072249  1.051464      1.051464      1.051464
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 3265                   0.0                         0.0
# 3266                   0.0                         0.0
# 3267                   0.0                         0.0
# 3268                   0.0                         0.0
# 3269                   0.0                         0.0
#
#       multiplicative_terms_upper      yhat
# 3265                         0.0  8.203200
# 3266                         0.0  8.528241
# 3267                         0.0  8.315636
# 3268                         0.0  8.148223
# 3269                         0.0  8.160140

# %% [markdown]
# - You can plot the forecast by calling the `Prophet.plot` method and passing in the `forecast` dataframe.

# %%
fig1 = model.plot(forecast, figsize=(14, 4))

# %% [markdown]
# - If you want to see the forecast components, you can use the `Prophet.plot_components` method.
# - By default you’ll see the trend, yearly seasonality, and weekly seasonality of the time series.
# - If you include holidays, you’ll see those here, too.

# %%
fig2 = model.plot_components(forecast, figsize=(7, 6))

# %% [markdown]
# An interactive figure of the forecast and components can be created with `plotly`:

# %% [markdown]
# ```python
# from prophet.plot import plot_plotly, plot_components_plotly
#
# plot_plotly(model, forecast)
# plot_components_plotly(model, forecast)
# ```

# %%
from prophet.plot import plot_plotly, plot_components_plotly

#plot_plotly(model, forecast)
#plot_components_plotly(model, forecast)

# %% [markdown]
# ### Modeling holidays and special events
#
# - If you have holidays or other recurring events that you’d like to model, you must create a dataframe for them.
# - It has two columns (`holiday` and `ds`) and a row for each occurrence of the holiday.
# - It must include all occurrences of the holiday, both in the past (back as far as the historical data go) and in the future (out as far as the forecast is being made).
# - If they won’t repeat in the future, Prophet will model them and then not include them in the forecast.

# %% [markdown]
# - You can also include columns `lower_window` and `upper_window` which extend the holiday out to [`lower_window`, `upper_window`] days around the date.
# - For instance, if you wanted to include Christmas Eve in addition to Christmas you’d include `'lower_window': -1` and `'upper_window': 0`.
#
# Here we create a dataframe that includes the dates of all of Peyton Manning’s playoff appearances:

# %%
# add holidays 
playoffs = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(['2008-01-13', '2009-01-03', '2010-01-16',
                        '2010-01-24', '2010-02-07', '2011-01-08',
                        '2013-01-12', '2014-01-12', '2014-01-19',
                        '2014-02-02', '2015-01-11', '2016-01-17',
                        '2016-01-24', '2016-02-07']),
  'lower_window': 0, # this specifies spillover into previous days
  'upper_window': 1, # this for the future days
})

superbowls = pd.DataFrame({
  'holiday': 'superbowl',
  'ds': pd.to_datetime(['2010-02-07', '2014-02-02', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})

holidays_df = pd.concat((playoffs, superbowls))

# %% [markdown]
# - Above we have included the superbowl days as both playoff games and superbowl games.
# - This means that the superbowl effect will be an additional additive bonus on top of the playoff effect.

# %% [markdown]
# Once `holidays_df` is created, holiday effects are included in the forecast by passing them in with the `holidays` argument of the constructor.

# %%
# fit and predict
model_holyday = Prophet(holidays=holidays_df, # this includes the holidays
                        growth='linear', seasonality_mode='additive', interval_width=0.90) # these are unchanged
forecast = model_holyday.fit(peyton).predict(future)
# Out:
# 15:15:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:06 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# We can see the effects of various holidays on site visits.

# %%
forecast[(forecast['playoff'] + forecast['superbowl']).abs() > 0][
        ['ds', 'yhat', 'playoff', 'superbowl']][-10:]
# Out:
#              ds       yhat   playoff  superbowl
# 2190 2014-02-02  11.637592  1.222156   1.206153
# 2191 2014-02-03  12.842425  1.901229   1.455909
# 2532 2015-01-11   9.884875  1.222156   0.000000
# 2533 2015-01-12  10.896000  1.901229   0.000000
# 2901 2016-01-17   9.642170  1.222156   0.000000
# 2902 2016-01-18  10.656056  1.901229   0.000000
# 2908 2016-01-24   9.778466  1.222156   0.000000
# 2909 2016-01-25  10.782940  1.901229   0.000000
# 2922 2016-02-07  10.702300  1.222156   1.206153
# 2923 2016-02-08  11.880640  1.901229   1.455909

# %% [markdown]
# We can also check visually the impact of the holidays.

# %%
fig2 = model_holyday.plot_components(forecast, figsize=(7, 6))

# %% [markdown]
# - Now `plot_components` contains also the holidays component.
# - Peyton won the Superbowl in 2016 while losing in 2010 and 2014.
# - We can see these spikes in the holidays chart.

# %% [markdown]
# - You can use a built-in collection of country-specific holidays using the `add_country_holidays`.
# - The name of the country is specified, and then major holidays for that country will be included in addition to any holidays that are specified via the holidays argument described before.
# - A list of available countries and the country code is availble [here](https://github.com/vacanza/python-holidays/).

# %%
model_holyday2 = Prophet(holidays=holidays_df) # this includes the holidays we specified by hand
model_holyday2.add_country_holidays(country_name='Netherlands') # this the country-specific holidays
model_holyday2.fit(peyton)
print(model_holyday2.train_holiday_names)
# Out:
# 16:19:12 - cmdstanpy - INFO - Chain [1] start processing
# 16:19:12 - cmdstanpy - INFO - Chain [1] done processing
# 0                     playoff
# 1                   superbowl
# 2              New Year's Day
# 3               Easter Sunday
# 4               Easter Monday
# 5                  King's Day
# 6               Ascension Day
# 7                 Whit Sunday
# 8                 Whit Monday
# 9               Christmas Day
# 10    Second Day of Christmas
# 11                Queen's Day
# 12             Liberation Day
# dtype: object

# %% [markdown]
# As before, the country-level holidays will then show up in the components plot.

# %%
forecast = model_holyday2.predict(future)
fig = model_holyday2.plot_components(forecast, figsize=(7, 6))

# %% [markdown]
# ### Saturating forecasts
#
# - As discussed previously, Prophet allows you to make forecasts using a logistic growth trend model.
# - Here, we will use a time series from the [Datasets Package](https://www.statsmodels.org/stable/datasets/index.html) from `statsmodels`.
# - The list of available datasets is [here](https://vincentarelbundock.github.io/Rdatasets/articles/data.html).
# - We need to do a bit of data preproccesing before using the data.

# %%
co2 = sm.datasets.get_rdataset("co2", "datasets").data
print(co2.head())
# Out:
#           time   value
# 0  1959.000000  315.42
# 1  1959.083333  316.31
# 2  1959.166667  316.50
# 3  1959.250000  317.56
# 4  1959.333333  318.13

# %%
# Convert decimal year to pandas datetime
def convert_decimal_year_to_datetime(decimal_years):
    dates = [(pd.to_datetime(f'{int(year)}-01-01') + pd.to_timedelta((year - int(year)) * 365.25, unit='D')).date() 
             for year in decimal_years]
    return dates

# Convert to Prophet format
co2['time'] = convert_decimal_year_to_datetime(co2['time'])
co2.rename(columns={'time': 'ds', 'value': 'y'}, inplace=True)

# Convert the column ds to datetime
co2['ds'] = pd.to_datetime(co2['ds'])
print("\nConverted:\n------------------\n", co2.head())
# Out:
# Converted:
# ------------------
#            ds       y
# 0 1959-01-01  315.42
# 1 1959-01-31  316.31
# 2 1959-03-02  316.50
# 3 1959-04-02  317.56
# 4 1959-05-02  318.13

# %%
# Resample to monthly frequency based on the ds column
co2 = co2.resample('MS', on='ds').mean().reset_index()

# Replace NaN with the mean of the previous and next value
co2['y'] = co2['y'].interpolate()
print("\nResampled:\n------------------\n", co2.head())
# Out:
# Resampled:
# ------------------
#            ds         y
# 0 1959-01-01  315.8650
# 1 1959-02-01  316.1825
# 2 1959-03-01  316.5000
# 3 1959-04-01  317.5600
# 4 1959-05-01  318.1300

# %% [markdown]
# Next, we split the data in training set (first 90% of the data) and test set (remaining 10%).

# %%
# Note that we need to make a copy here since we will modify the data
train = co2.iloc[:int(co2.shape[0] * 0.9)].copy()
test = co2.iloc[int(co2.shape[0] * 0.9):].copy()

fig, ax = plt.subplots(figsize=(10, 4))
train.plot(x='ds', y='y', figsize=(14, 4), grid=True, ax=ax)
test.plot(x='ds', y='y', figsize=(14, 4), grid=True, ax=ax)
plt.show()

# %% [markdown]
# - The logistic model requires to specify a carrying capacity, i.e., the maximum achievable point (total market size, total population size, etc..).
# - The carrying capacity is specified in a column `cap`.
# - Here we will set an arbitrary value, but this would normally be set based on expertise and knowledge about the data.

# %%
train['cap'] = 360

# %% [markdown]
# We then fit the model as before, except we change `growth='linear'` into `growth='logistic'`.

# %%
model_logist = Prophet(growth='logistic', # this has changed
                       seasonality_mode='additive', interval_width=0.90)
model_logist.fit(train);
# Out:
# 15:15:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:39 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# - We make a dataframe for future predictions as before, except we must also specify the capacity in the future.
# - Here we set the capacity at the same value we used for historical data (`train['cap'] = 360`).
# - Finally, we compute the forecast for the dates in the test set.

# %%
future = future = pd.DataFrame({'ds': pd.concat([train['ds'], test['ds']])}) # Init df for predictions
future['cap'] = 360                                                          # Set the cap
fcst = model_logist.predict(future)                                          # Compute forecasts
fig, ax = plt.subplots(figsize=(14, 4))
fig = model_logist.plot(fcst, ax=ax)
ax.plot(test['ds'], test['y'], 'tab:red', marker='o', markersize=3, alpha=0.5);

# %% [markdown]
# - The model tries to keep the predictions under the specified `cap` value.
# - The value is clearly too low in this case. Try with `cap=380` to get better predictions.

# %% [markdown]
# - The logistic growth model can also handle a saturating minimum.
# - This is specified with a column `floor` in the same way as the `cap` column specifies the maximum.
# - To use a logistic growth trend with a saturating minimum, a maximum capacity must also be specified.

# %%
train['y'] = 400 - train['y'] # Modify the data so that the time series decreases over time
train['cap'] = 85
train['floor'] = 40
future['cap'] = 85
future['floor'] = 40
m = Prophet(growth='logistic')
m.fit(train)
fcst = m.predict(future)
fig = m.plot(fcst, figsize=(14, 4))
# Out:
# 15:15:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:52 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ### Trend changepoints
#
# - Real time series frequently have abrupt changes in their trajectories.
# - By default, Prophet will automatically detect these changepoints and will allow the trend to adapt appropriately.
# - However, if you wish to have finer control over this process (e.g., Prophet missed a rate change, or is overfitting rate changes in the history), then there are several input arguments you can use.

# %% [markdown]
# - Prophet detects changepoints by first specifying a large number of potential changepoints at which the rate is allowed to change.
# - Through a L1 regularization that encourages sparsity, it use as few of them as possible.
# - Let's consider again the Peyton Manning data.

# %%
# Data already log-transformed
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
# Out:
# 15:15:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:55 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# - Prophet specifies 25 *potential changepoints* which are uniformly placed in the first 80% of the time series.
# - The vertical lines indicate where the potential changepoints were placed.

# %%
from prophet.plot import add_changepoints_to_plot
fig = m.plot(forecast, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), m, forecast, threshold=0.0, cp_color='gray', trend=False)

# %% [markdown]
# - Even though we have a lot of places where the rate can possibly change, because of the sparse prior, most of these changepoints are not used.
# - We can see this by plotting the magnitude of the rate change at each changepoint.
# - We keep only those where the magnitude of the rate change is significant.

# %%
fig, ax = plt.subplots(figsize=(7, 4))
eps = 5e-3  # small offset to improve visualization
ax.bar(m.changepoints, np.nanmean(m.params['delta'], axis=0)+eps, color='k', width=40)
ax.fill_between(ax.get_xlim(), 0.01+eps, -0.01-eps, color='r', alpha=0.2, label='Significance Level')
ax.set_title('Change Points')
ax.set_ylabel('Rate change')
ax.set_xlabel('Potential Changepoints')
plt.legend()
plt.show()

# %% [markdown]
# - Only 9 out of 25 potential changepoints are actually kept.
# - We can visualize them on the actual data.

# %%
fig = m.plot(forecast, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), m, forecast, threshold=0.01, cp_color='tab:red', trend=True)

# %% [markdown]
# - By default changepoints are only inferred for the first 80% of the time series.
# - This allows having plenty of runway for projecting the trend forward and to avoid overfitting fluctuations at the end of the time series.
# - This default works in many situations but not all, and can be changed using the `changepoint_range` argument.
# - For example, `m = Prophet(changepoint_range=0.9)` will place potential changepoints in the first 90% of the time series.
# - This can be useful in situation where there are important changes in the trend towards the end of the time series.

# %% [markdown]
# #### Adjusting trend flexibility
#
# - If the trend changes are being overfit (too much flexibility) or underfit (not enough flexibility), you can adjust the strength of the sparsity prior using the input argument `changepoint_prior_scale`.
# - By default, this parameter is set to 0.05.
# - Increasing it will make the trend more flexible.

# %%
m = Prophet(changepoint_prior_scale=0.5) # Increase prior
forecast = m.fit(df).predict(future)
fig = m.plot(forecast, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), m, forecast, threshold=0.01, cp_color='tab:red', trend=True)
# Out:
# 15:16:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:21 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# Decreasing it will make the trend less flexible.

# %%
m = Prophet(changepoint_prior_scale=0.001) # Decrease prior
forecast = m.fit(df).predict(future)
fig = m.plot(forecast, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), m, forecast, threshold=0.01, cp_color='tab:red', trend=True)
# Out:
# 15:16:31 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:32 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### Specifying the locations of the changepoints
#
# - You can manually specify the locations of potential changepoints with the `changepoints` argument.
# - Slope changes will then be allowed only at these points, with the same sparse regularization as before.
# - One could, for instance, create automatically a grid of points.
# - Then, augment the grid with some specific dates that are known to be likely to have changes.
# - Alternatively, the changepoints could be entirely limited to a small set of dates, as is done here.

# %%
m = Prophet(changepoints=['2014-01-01'])
forecast = m.fit(df).predict(future)
fig = m.plot(forecast, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), m, forecast, threshold=0.01, cp_color='tab:red', trend=True)
# Out:
# 15:16:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:40 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# - Prophet's methodology offers a flexible and intuitive approach to time series forecasting.
# - By decomposing the time series into trend, seasonality, and holiday components, it captures various patterns in the data.
# - Using Fourier series for seasonality and logistic or piece-wise linear growth for the trend allows Prophet to handle a wide range of forecasting scenarios.
#
# ---

# %% [markdown]
# ## Exercises
#
# Let's consider a time series of monthly retail sales index in the Netherlands from 1960 to 1995.

# %%
sales = sm.datasets.get_rdataset("DutchSales", "AER").data
print("Raw data:\n------------------\n", sales.head())
# Out:
# Raw data:
# ------------------
#            time  value
# 0  1960.333333     14
# 1  1960.416667     13
# 2  1960.500000     15
# 3  1960.583333     13
# 4  1960.666667     13

# %% [markdown]
# 1. Do the required preproccesing and convert the data to Prophet format.
# 2. Split the data in training and test data, using the first 90% and last 10% of the time series, respectively.
# 3. Fit a Prophet model to the data using a linear trend and make a forecast for the period of the test data.
# 4. Make the forecast with a model that includes the national holidays.
# 5. Adjust the trend by modifying the `changepoint_range` and `changepoint_prior_scale`. For each parameter, try at least two different values from the default ones.
# 6. Make the forecasts with a model with logistic trend.
# 7. Compare the performance of the models obtained at steps 3-6 in terms of MSE and MAPE on the test data.

# %%
#1. adjusting the data to foramt required by Prophet YYYY-MM-DD HH:MM:SS

# Separate the integer year and fractional part
df['year'] = sales['time'].astype(int)
df['fraction'] = sales['time'] - df['year']
# Convert fractional part to days and add to Jan 1 of each year
df['ds'] = pd.to_datetime(df['year'], format='%Y') + pd.to_timedelta(df['fraction'] * 365.25, unit='D')
# Rename 'value' to 'y' for Prophet
df['y'] = sales['value']
# Keep only necessary columns
df = df[['ds', 'y']]
print(df.isnull().any().any())  
# Clean the data
df_clean = df.dropna()  # Remove any rows with NaN values
df_clean.head()
# Out:
# True
#                              ds     y
# 0 1960-05-01 17:59:59.999897149  14.0
# 1 1960-06-01 04:30:00.000102850  13.0
# 2 1960-07-01 15:00:00.000000000  15.0
# 3 1960-08-01 01:29:59.999897149  13.0
# 4 1960-08-31 12:00:00.000102850  13.0

# %%
print(df_clean.isnull().any().any())  #no NaN values should be present now
# Out:
# False

# %%
df_clean.describe()
# Out:
#                                   ds           y
# count                            425  425.000000
# mean   1977-12-31 21:06:21.176470592   63.442353
# min    1960-05-01 17:59:59.999897149   12.000000
# 25%    1969-03-02 21:00:00.000102848   30.000000
# 50%              1978-01-01 00:00:00   73.000000
# 75%    1986-11-01 08:59:59.999897152   88.000000
# max    1995-09-01 12:00:00.000102850  131.000000
# std                              NaN   32.215110

# %%
ds_indexed = df.set_index('ds')
ds_indexed.plot(figsize=(12, 6), title='Dutch Sales Data', grid=True, ylabel='Sales', xlabel='Date');

# %% [markdown]
# Time series with seasonality and significant trend - no need of applying log

# %%
#2. Splitting the data into training and testing sets
# Determine split index
split_index = int(len(df_clean) * 0.9)
# Split
train_df = df_clean.iloc[:split_index]
test_df = df_clean.iloc[split_index:]
print(f"Training data: {len(train_df)} rows")
print(f"Test data: {len(test_df)} rows")
# Out:
# Training data: 382 rows
# Test data: 43 rows

# %%
test_df
# Out:
#                                ds      y
# 382 1992-03-01 21:00:00.000102850  100.0
# 383 1992-04-01 07:30:00.000000000  107.0
# 384 1992-05-01 17:59:59.999897149  112.0
# 385 1992-06-01 04:30:00.000102850  106.0
# 386 1992-07-01 15:00:00.000000000  109.0
# 387 1992-08-01 01:29:59.999897149  101.0
# 388 1992-08-31 12:00:00.000102850  107.0
# 389 1992-09-30 22:30:00.000000000  116.0
# 390 1992-10-31 08:59:59.999897149  105.0
# 391 1992-11-30 19:30:00.000102850  128.0
# 392 1993-01-01 00:00:00.000000000   98.0
# 393 1993-01-31 10:29:59.999897149   90.0
# 394 1993-03-02 21:00:00.000102850  106.0
# 395 1993-04-02 07:30:00.000000000  110.0
# 396 1993-05-02 17:59:59.999897149  111.0
# 397 1993-06-02 04:30:00.000102850  112.0
# 398 1993-07-02 15:00:00.000000000  114.0
# 399 1993-08-02 01:29:59.999897149  102.0
# 400 1993-09-01 12:00:00.000102850  111.0
# 401 1993-10-01 22:30:00.000000000  113.0
# 402 1993-11-01 08:59:59.999897149  109.0
# 403 1993-12-01 19:30:00.000102850  129.0
# 404 1994-01-01 00:00:00.000000000   97.0
# 405 1994-01-31 10:29:59.999897149   92.0
# 406 1994-03-02 21:00:00.000102850  110.0
# 407 1994-04-02 07:30:00.000000000  110.0
# 408 1994-05-02 17:59:59.999897149  109.0
# 409 1994-06-02 04:30:00.000102850  114.0
# 410 1994-07-02 15:00:00.000000000  109.0
# 411 1994-08-02 01:29:59.999897149  104.0
# 412 1994-09-01 12:00:00.000102850  114.0
# 413 1994-10-01 22:30:00.000000000  111.0
# 414 1994-11-01 08:59:59.999897149  111.0
# 415 1994-12-01 19:30:00.000102850  131.0
# 416 1995-01-01 00:00:00.000000000   98.0
# 417 1995-01-31 10:29:59.999897149   93.0
# 418 1995-03-02 21:00:00.000102850  111.0
# 419 1995-04-02 07:30:00.000000000  107.0
# 420 1995-05-02 17:59:59.999897149  114.0
# 421 1995-06-02 04:30:00.000102850  116.0
# 422 1995-07-02 15:00:00.000000000  107.0
# 423 1995-08-02 01:29:59.999897149  106.0
# 424 1995-09-01 12:00:00.000102850  115.0

# %%
fig, ax = plt.subplots(figsize=(10, 4))
train_df.plot(x='ds', y='y', figsize=(14, 4), grid=True, ax=ax)
test_df.plot(x='ds', y='y', figsize=(14, 4), grid=True, ax=ax)
plt.show()

# %%
# Calculate the correct number of days to forecast
last_train_date = train_df['ds'].max()
last_test_date = test_df['ds'].max()
total_months_to_forecast = (last_test_date - last_train_date).days // 30

print(f"Total months to forecast: {total_months_to_forecast == len(test_df)}")
# Out:
# Total months to forecast: True

# %%
#3. Fit a Prophet model to the data using a linear trend and make a forecast for the period of the test data (monthly frequency)
model_dutch = Prophet(
    growth='linear', 
    seasonality_mode='additive', 
    interval_width=0.90
)

# Fit the model on training data
model_dutch.fit(train_df)

future_dutch = model_dutch.make_future_dataframe(
    periods=total_months_to_forecast, 
    freq='M', 
    include_history=True
)

forecast_dutch = model_dutch.predict(future_dutch)

print("\nLast few rows of forecast:")
print(forecast_dutch[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 17:05:24 - cmdstanpy - INFO - Chain [1] start processing
# 17:05:24 - cmdstanpy - INFO - Chain [1] done processing
# Last few rows of forecast:
#                                ds        yhat  yhat_lower  yhat_upper
# 420 1995-04-30 10:29:59.999897149  115.596400  109.918219  121.431387
# 421 1995-05-31 10:29:59.999897149  114.161556  108.143662  120.078565
# 422 1995-06-30 10:29:59.999897149  113.537518  107.657780  120.186443
# 423 1995-07-31 10:29:59.999897149  112.039097  106.345686  118.171260
# 424 1995-08-31 10:29:59.999897149  115.082056  108.830104  121.628959

# %%
fig, ax = plt.subplots(figsize=(14, 4))
fig = model_dutch.plot(forecast_dutch, ax=ax)
ax.plot(test_df['ds'], test_df['y'], 'tab:red', marker='o', markersize=3, alpha=0.5);

# %%
model_dutch.plot_components(forecast_dutch, figsize=(7, 6));

# %%
from sklearn.metrics import mean_squared_error
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

test_to_mse_1 = test_df[['ds', 'y']]
forcast_to_mse_1 = forecast_dutch[['ds', 'yhat']].tail(43)
# Calculate MSE
mse_model_1 = mean_squared_error(test_df['y'], forcast_to_mse_1['yhat'])
print(f"Mean Squared Error (MSE) on test data: {mse_model_1:.2f}")
#Calculate MAPE
mape_model_1 = mean_absolute_percentage_error(test_df['y'], forcast_to_mse_1['yhat'])
print(f"Mean Absolute Percantego Error (MAPE) on test data: {mape_model_1:.2f}")
# Out:
# Mean Squared Error (MSE) on test data: 34.64
# Mean Absolute Percantego Error (MAPE) on test data: 4.38

# %%
#4. Fitting the model with holidays
model_dutch_with_holidays = Prophet(
    growth='linear', 
    seasonality_mode='additive', 
    interval_width=0.90,
)
model_dutch_with_holidays.add_country_holidays(country_name='Netherlands') 

# Fit the model with holidays on training data
model_dutch_with_holidays.fit(train_df)

print(model_dutch_with_holidays.train_holiday_names)

future_dutch_holidays = model_dutch_with_holidays.make_future_dataframe(
    periods=total_months_to_forecast, 
    freq='M', 
    include_history=True
)

forecast_dutch_with_holidays = model_dutch_with_holidays.predict(future_dutch_holidays)
# Out:
# 17:07:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:06 - cmdstanpy - INFO - Chain [1] done processing
# 0             New Year's Day
# 1              Easter Sunday
# 2              Easter Monday
# 3                Queen's Day
# 4             Liberation Day
# 5              Ascension Day
# 6                Whit Sunday
# 7                Whit Monday
# 8              Christmas Day
# 9    Second Day of Christmas
# dtype: object

# %%
print("\nLast few rows of forecast:")
print(forecast_dutch_with_holidays[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# Last few rows of forecast:
#                                ds        yhat  yhat_lower  yhat_upper
# 420 1995-04-30 10:29:59.999897149  116.031745  110.309651  121.733412
# 421 1995-05-31 10:29:59.999897149  113.839126  107.710148  119.668628
# 422 1995-06-30 10:29:59.999897149  113.108049  106.924572  118.628769
# 423 1995-07-31 10:29:59.999897149  111.713965  105.476348  117.532709
# 424 1995-08-31 10:29:59.999897149  114.809192  108.475210  120.933403

# %%
fig, ax = plt.subplots(figsize=(14, 4))
fig = model_dutch_with_holidays.plot(forecast_dutch_with_holidays, ax=ax)
ax.plot(test_df['ds'], test_df['y'], 'tab:red', marker='o', markersize=3, alpha=0.5);

# %%
model_dutch_with_holidays.plot_components(forecast_dutch_with_holidays, figsize=(7, 6));

# %%
forcast_to_mse_2 = forecast_dutch_with_holidays[['ds', 'yhat']].tail(43)
# Calculate MSE
mse_model_2 = mean_squared_error(test_df['y'], forcast_to_mse_2['yhat'])
print(f"Mean Squared Error (MSE) on test data: {mse_model_2:.2f}")
#Calculate MAPE
mape_model_2 = mean_absolute_percentage_error(test_df['y'], forcast_to_mse_2['yhat'])
print(f"Mean Absolute Percantego Error (MAPE) on test data: {mape_model_2:.2f}")
# Out:
# Mean Squared Error (MSE) on test data: 34.42
# Mean Absolute Percantego Error (MAPE) on test data: 4.36

# %%
#5 Fitting the model with holidays and changepoints - performing a grid search to find the best changepoint prior scale

fig = model_dutch_with_holidays.plot(forecast_dutch_with_holidays, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), model_dutch_with_holidays, forecast_dutch_with_holidays, threshold=0.0, cp_color='gray', trend=False)

# %%
fig, ax = plt.subplots(figsize=(7, 4))
eps = 5e-3  # small offset to improve visualization
ax.bar(model_dutch_with_holidays.changepoints, np.nanmean(model_dutch_with_holidays.params['delta'], axis=0)+eps, color='k', width=40)
ax.fill_between(ax.get_xlim(), 0.01+eps, -0.01-eps, color='r', alpha=0.2, label='Significance Level')
ax.set_title('Change Points')
ax.set_ylabel('Rate change')
ax.set_xlabel('Potential Changepoints')
plt.legend()
plt.show()

# %%
model_dutch_with_holidays.changepoints
# Out:
# 12    1961-05-02 17:59:59.999897149
# 24    1962-05-02 17:59:59.999897149
# 36    1963-05-02 17:59:59.999897149
# 49    1964-06-01 04:30:00.000102850
# 61    1965-06-02 04:30:00.000102850
# 73    1966-06-02 04:30:00.000102850
# 85    1967-06-02 04:30:00.000102850
# 97    1968-06-01 04:30:00.000102850
# 109   1969-06-02 04:30:00.000102850
# 122   1970-07-02 15:00:00.000000000
# 134   1971-07-02 15:00:00.000000000
# 146   1972-07-01 15:00:00.000000000
# 158   1973-07-02 15:00:00.000000000
# 170   1974-07-02 15:00:00.000000000
# 182   1975-07-02 15:00:00.000000000
# 195   1976-08-01 01:29:59.999897149
# 207   1977-08-02 01:29:59.999897149
# 219   1978-08-02 01:29:59.999897149
# 231   1979-08-02 01:29:59.999897149
# 243   1980-08-01 01:29:59.999897149
# 255   1981-08-02 01:29:59.999897149
# 268   1982-09-01 12:00:00.000102850
# 280   1983-09-01 12:00:00.000102850
# 292   1984-08-31 12:00:00.000102850
# 304   1985-09-01 12:00:00.000102850
# Name: ds, dtype: datetime64[ns]

# %% [markdown]
# Here we have 11 potential changepoints

# %%
fig = model_dutch_with_holidays.plot(forecast_dutch_with_holidays, figsize=(14, 4))
a = add_changepoints_to_plot(fig.gca(), model_dutch_with_holidays, forecast_dutch_with_holidays, threshold=0.01, cp_color='tab:red', trend=True)

# %%
#grid search for changepoint prior scale
changepoint_ranges = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
changepoint_prior_scales = [0.01, 0.02, 0.03, 0.035, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
# the changepoint_range parameter controls where in your time series Prophet is allowed to automatically place potential changepoints (places where the trend can change).
# changepoint_prior_scale in Prophet controls how flexible the trend is at changepoints:

def grid_search_changepoints(train_df, test_df, total_months_to_forecast, changepoint_ranges, changepoint_prior_scales):

    results = []

    for cp_range in changepoint_ranges:
        for cp_scale in changepoint_prior_scales:
            model = Prophet(
                growth='linear',
                seasonality_mode='additive',
                interval_width=0.90,
                changepoint_range=cp_range,
                changepoint_prior_scale=cp_scale
            )
            model.add_country_holidays(country_name='Netherlands')
            model.fit(train_df)
            future = model.make_future_dataframe(
                periods=total_months_to_forecast,
                freq='M',
                include_history=True
            )
            forecast = model.predict(future)
            # Align forecast with test set
            forecast_test = forecast[['ds', 'yhat']].tail(len(test_df)).reset_index(drop=True)
            mse = mean_squared_error(test_df['y'].reset_index(drop=True), forecast_test['yhat'])
            results.append({
                'changepoint_range': cp_range,
                'changepoint_prior_scale': cp_scale,
                'mse': mse
            })
            print(f"cp_range={cp_range}, cp_scale={cp_scale}, MSE={mse:.2f}")

    return pd.DataFrame(results)

result_first_search = grid_search_changepoints(train_df, test_df, total_months_to_forecast, changepoint_ranges, changepoint_prior_scales)
# Out:
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.01, MSE=40.86
# cp_range=0.5, cp_scale=0.02, MSE=38.70
# cp_range=0.5, cp_scale=0.03, MSE=41.94
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.035, MSE=43.44
# cp_range=0.5, cp_scale=0.05, MSE=45.76
# cp_range=0.5, cp_scale=0.1, MSE=49.97
# 17:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.15, MSE=50.51
# cp_range=0.5, cp_scale=0.2, MSE=52.11
# cp_range=0.5, cp_scale=0.25, MSE=52.83
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.3, MSE=53.46
# cp_range=0.5, cp_scale=0.35, MSE=53.72
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.4, MSE=54.59
# cp_range=0.5, cp_scale=0.45, MSE=54.68
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:54 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.5, cp_scale=0.5, MSE=55.05
# cp_range=0.6, cp_scale=0.01, MSE=50.30
# cp_range=0.6, cp_scale=0.02, MSE=66.12
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.03, MSE=69.37
# cp_range=0.6, cp_scale=0.035, MSE=69.74
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.05, MSE=71.43
# cp_range=0.6, cp_scale=0.1, MSE=70.41
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.15, MSE=70.99
# cp_range=0.6, cp_scale=0.2, MSE=71.55
# cp_range=0.6, cp_scale=0.25, MSE=71.98
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.3, MSE=71.63
# cp_range=0.6, cp_scale=0.35, MSE=70.35
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.4, MSE=70.22
# cp_range=0.6, cp_scale=0.45, MSE=69.41
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.6, cp_scale=0.5, MSE=69.88
# cp_range=0.7, cp_scale=0.01, MSE=51.02
# cp_range=0.7, cp_scale=0.02, MSE=65.90
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.7, cp_scale=0.03, MSE=60.51
# cp_range=0.7, cp_scale=0.035, MSE=58.73
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.7, cp_scale=0.05, MSE=48.68
# cp_range=0.7, cp_scale=0.1, MSE=43.86
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.7, cp_scale=0.15, MSE=42.04
# cp_range=0.7, cp_scale=0.2, MSE=41.45
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# cp_range=0.7, cp_scale=0.25, MSE=41.07
# cp_range=0.7, cp_scale=0.3, MSE=40.46
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.7, cp_scale=0.35, MSE=39.40
# cp_range=0.7, cp_scale=0.4, MSE=39.42
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.7, cp_scale=0.45, MSE=39.60
# cp_range=0.7, cp_scale=0.5, MSE=39.04
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.01, MSE=51.83
# cp_range=0.8, cp_scale=0.02, MSE=37.57
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.03, MSE=34.41
# cp_range=0.8, cp_scale=0.035, MSE=34.14
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.05, MSE=34.42
# cp_range=0.8, cp_scale=0.1, MSE=36.15
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:58 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.15, MSE=36.98
# cp_range=0.8, cp_scale=0.2, MSE=37.29
# 17:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.25, MSE=37.69
# cp_range=0.8, cp_scale=0.3, MSE=37.74
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.35, MSE=38.15
# cp_range=0.8, cp_scale=0.4, MSE=37.75
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.45, MSE=38.17
# cp_range=0.8, cp_scale=0.5, MSE=38.11
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.01, MSE=54.39
# cp_range=0.9, cp_scale=0.02, MSE=37.84
# cp_range=0.9, cp_scale=0.03, MSE=49.31
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.035, MSE=56.17
# cp_range=0.9, cp_scale=0.05, MSE=66.89
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.1, MSE=87.36
# cp_range=0.9, cp_scale=0.15, MSE=100.49
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.2, MSE=100.89
# cp_range=0.9, cp_scale=0.25, MSE=105.70
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# cp_range=0.9, cp_scale=0.3, MSE=106.81
# cp_range=0.9, cp_scale=0.35, MSE=107.26
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.4, MSE=107.59
# cp_range=0.9, cp_scale=0.45, MSE=108.67
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.9, cp_scale=0.5, MSE=108.78
# cp_range=1.0, cp_scale=0.01, MSE=56.18
# cp_range=1.0, cp_scale=0.02, MSE=38.96
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=1.0, cp_scale=0.03, MSE=47.61
# cp_range=1.0, cp_scale=0.035, MSE=54.50
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=1.0, cp_scale=0.05, MSE=63.00
# cp_range=1.0, cp_scale=0.1, MSE=90.81
# 17:08:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=1.0, cp_scale=0.15, MSE=97.30
# cp_range=1.0, cp_scale=0.2, MSE=103.79
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# cp_range=1.0, cp_scale=0.25, MSE=104.10
# cp_range=1.0, cp_scale=0.3, MSE=97.66
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# cp_range=1.0, cp_scale=0.35, MSE=97.77
# cp_range=1.0, cp_scale=0.4, MSE=105.11
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:02 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=1.0, cp_scale=0.45, MSE=96.40
# cp_range=1.0, cp_scale=0.5, MSE=103.66

# %%
result_first_search.sort_values('mse')
# Out:
#     changepoint_range  changepoint_prior_scale         mse
# 45                0.8                    0.035   34.141987
# 44                0.8                    0.030   34.412677
# 46                0.8                    0.050   34.424236
# 47                0.8                    0.100   36.146093
# 48                0.8                    0.150   36.976756
# ..                ...                      ...         ...
# 65                0.9                    0.300  106.808207
# 66                0.9                    0.350  107.257452
# 67                0.9                    0.400  107.592575
# 68                0.9                    0.450  108.673107
# 69                0.9                    0.500  108.784859
#
# [84 rows x 3 columns]

# %%
#the best parameters are changepoint_range=0.8 and changepoint_prior_scale around 0.035 so let's repeat the fitting with parameters around these values

#grid search for changepoint prior scale
changepoint_ranges2 = [0.8]
changepoint_prior_scales2 = np.arange(0.03, 0.04, 0.001).tolist()  # [0.03, 0.035, 0.04]
result_2nd_search = grid_search_changepoints(train_df, test_df, total_months_to_forecast, changepoint_ranges2, changepoint_prior_scales2)
# Out:
# 17:08:18 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:18 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:18 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:18 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:18 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:18 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.03, MSE=34.41
# cp_range=0.8, cp_scale=0.031, MSE=34.18
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.032, MSE=33.87
# cp_range=0.8, cp_scale=0.033, MSE=34.21
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.034, MSE=33.95
# cp_range=0.8, cp_scale=0.035, MSE=34.14
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.036000000000000004, MSE=34.08
# cp_range=0.8, cp_scale=0.037000000000000005, MSE=34.18
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:19 - cmdstanpy - INFO - Chain [1] done processing
# cp_range=0.8, cp_scale=0.038000000000000006, MSE=34.29
# cp_range=0.8, cp_scale=0.03900000000000001, MSE=34.27
# cp_range=0.8, cp_scale=0.04000000000000001, MSE=34.08

# %%
result_2nd_search.sort_values('mse')
# Out:
#     changepoint_range  changepoint_prior_scale        mse
# 2                 0.8                    0.032  33.865769
# 4                 0.8                    0.034  33.945549
# 6                 0.8                    0.036  34.075392
# 10                0.8                    0.040  34.082942
# 5                 0.8                    0.035  34.141987
# 7                 0.8                    0.037  34.175435
# 1                 0.8                    0.031  34.181248
# 3                 0.8                    0.033  34.213385
# 9                 0.8                    0.039  34.269484
# 8                 0.8                    0.038  34.291690
# 0                 0.8                    0.030  34.412677

# %%
#now let's visualize this forecast: 

model_3 = Prophet(
growth='linear',
seasonality_mode='additive',
interval_width=0.90,
changepoint_range=0.8,
changepoint_prior_scale=0.032
)
model_3.add_country_holidays(country_name='Netherlands')
model_3.fit(train_df)
future_3 = model_3.make_future_dataframe(
periods=total_months_to_forecast,
freq='M',
include_history=True
)
forecast_3 = model.predict(future_3)

fig, ax = plt.subplots(figsize=(14, 4))
fig = model_3.plot(forecast_3, ax=ax)
ax.plot(test_df['ds'], test_df['y'], 'tab:red', marker='o', markersize=3, alpha=0.5);
# Out:
# 17:08:23 - cmdstanpy - INFO - Chain [1] start processing
# 17:08:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
forcast_to_mse_3 = forecast_3[['ds', 'yhat']].tail(43)
# Calculate MSE
mse_model_3 = mean_squared_error(test_df['y'], forcast_to_mse_3['yhat'])
print(f"Mean Squared Error (MSE) on test data: {mse_model_3:.2f}")
#Calculate MAPE
mape_model_3 = mean_absolute_percentage_error(test_df['y'], forcast_to_mse_3['yhat'])
print(f"Mean Absolute Percantego Error (MAPE) on test data: {mape_model_3:.2f}")
# Out:
# Mean Squared Error (MSE) on test data: 33.87
# Mean Absolute Percantego Error (MAPE) on test data: 4.25

# %%
## 6. model forcast with logistic trend 

print(train_df['y'].min(), train_df['y'].max())
print(test_df['y'].min(), test_df['y'].max())
# Out:
# 12.0 119.0
# 90.0 131.0

# %%
floor = train_df['y'].min() * 1.05  # or just slightly below min
cap = train_df['y'].max() * 0.95   # or just slightly above max
train_df['cap'] = cap  # Set the carrying capacity for logistic growth
train_df['floor'] = floor  # Set the floor for logistic growth

model_logistic = Prophet(
    growth='logistic',
    seasonality_mode='additive',
    interval_width=0.90,
    changepoint_range=0.8,
    changepoint_prior_scale=0.032
)
model_logistic.add_country_holidays(country_name='Netherlands')
# Fit the model on training data
model_logistic.fit(train_df)
future_logistic = model_logistic.make_future_dataframe(
    periods=total_months_to_forecast,
    freq='M',
    include_history=True
)  
future_logistic['cap'] = cap  # Set the carrying capacity
future_logistic['floor'] = floor  # Set the floor for logistic growth
forecast_logistic = model_logistic.predict(future_logistic)
fig, ax = plt.subplots(figsize=(14, 4))
fig = model_logistic.plot(forecast_logistic, ax=ax)
ax.plot(test_df['ds'], test_df['y'], 'tab:red', marker='o', markersize=3, alpha=0.5);
# Calculate MSE for logistic model
forcast_to_mse_4 = forecast_logistic[['ds', 'yhat']].tail(43)
mse_model_4 = mean_squared_error(test_df['y'], forcast_to_mse_4['yhat'])
print(f"Mean Squared Error (MSE) on test data for logistic model: {mse_model_4:.2f}")
mape_model_4 = mean_absolute_percentage_error(test_df['y'], forcast_to_mse_4['yhat'])
print(f"Mean Absolute Percantego Error (MAPE) on test data: {mape_model_4:.2f}")
# Out:
# 17:10:31 - cmdstanpy - INFO - Chain [1] start processing
# 17:10:31 - cmdstanpy - INFO - Chain [1] done processing
# Mean Squared Error (MSE) on test data for logistic model: 963.15
# Mean Absolute Percantego Error (MAPE) on test data: 16.27

# %% [markdown]
# ### Comment this model doesn't workj with logistic growth, linear is better

# %%
# 7. Comparision of MSE and MAPE between the models 

print("\nComparison of Models:")
print(f"{'Model':<30} {'MSE':<10} {'MAPE (%)':<10}")
print(f"{'Linear Model':<30} {mse_model_1:<10.2f} {mape_model_1:<10.2f}")
print(f"{'Linear Model with Holidays':<30} {mse_model_2:<10.2f} {mape_model_2:<10.2f}")
print(f"{'Linear Model with Holidays and Changepoints':<30} {mse_model_3:<10.2f} {mape_model_3:<10.2f}")
print(f"{'Logistic Model':<30} {mse_model_4:<10.2f} {mape_model_4:<10.2f}")
# 8. Visualizing the results of all models
fig, ax = plt.subplots(figsize=(14, 4))
train_df.plot(x='ds', y='y', label='Train Data', ax=ax, color='blue')
test_df.plot(x='ds', y='y', label='Test Data', ax=ax, color='red')
ax.plot(forecast_dutch['ds'], forecast_dutch['yhat'], label='Linear Model', color='green')
ax.plot(forecast_dutch_with_holidays['ds'], forecast_dutch_with_holidays['yhat'], label='Linear Model with Holidays', color='orange')
ax.plot(forecast_3['ds'], forecast_3['yhat'], label='Linear Model with Holidays and Changepoints', color='purple')
ax.plot(forecast_logistic['ds'], forecast_logistic['yhat'], label='Logistic Model', color='brown')
ax.set_title('Model Predictions vs Actual Data')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
ax.legend()
plt.show()
# Out:
# Comparison of Models:
# Model                          MSE        MAPE (%)
# Linear Model                   34.64      4.38
# Linear Model with Holidays     34.42      4.36
# Linear Model with Holidays and Changepoints 33.87      4.25
# Logistic Model                 963.15     16.27
